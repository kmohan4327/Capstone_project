# %%
# %sql
SELECT
  order_date,
  status,
  total_orders,
  distinct_customers
FROM phase8_lab.gold_daily_sales
ORDER BY order_date, status;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
SELECT
  order_date,
  status,
  total_orders,
  distinct_customers
FROM dbx_phase8.governance_lab.gold_sales_metrics_uc
ORDER BY distinct_customers, status;
